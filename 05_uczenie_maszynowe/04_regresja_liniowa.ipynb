# %% [markdown]
# Wygenerowanie danych

# %%
import numpy as np

X = np.arange(0, 50, 0.5)
noise = 10 * np.random.randn(100)
y = 2 * X + 100 + noise
X = X.reshape(-1, 1)

print('Rozmiar X: ', X.shape)
print('Rozmiar y: ', y.shape)
# Out:
# Rozmiar X:  (100, 1)
# Rozmiar y:  (100,)

# %% [markdown]
# Podział danych na zbiór treningowy i testowy

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)

print('X_train shape: ', X_train.shape)
print('X_test shape: ', X_test.shape)
print('y_train shape: ', y_train.shape)
print('y_test shape: ', y_test.shape)
# Out:
# X_train shape:  (75, 1)
# X_test shape:  (25, 1)
# y_train shape:  (75,)
# y_test shape:  (25,)

# %% [markdown]
# Wizualizacja

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

plt.figure(figsize=(7, 5))
plt.scatter(X_train, y_train, c='b', label='Zbiór treningowy')
plt.scatter(X_test, y_test, c='g', label='Zbiór testowy')

plt.xlabel('X')
plt.ylabel('y')
plt.legend()

# %% [markdown]
# Regresja liniowa

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)

print(lin_reg.coef_) # wartości wag
print(lin_reg.intercept_) # wartośc wyrazu wolnego
# Out:
# [2.13343526]
# 96.91092971610115

# %% [markdown]
# Rozwiązanie to prosta Y = 96.91 + 2.13 * X_1

# %% [markdown]
# Wizualizacja zbioru treningowego i dopasowanego modelu

# %%
plt.figure(figsize=(7, 5)) 
plt.title('Regresja Liniowa - jedna zmienna') 
plt.scatter(X_train, y_train, c='b', label='Zbiór treningowy') 
plt.plot(X, lin_reg.intercept_ + lin_reg.coef_[0] * X, c='red') 
plt.xlabel('X') 
plt.ylabel('y') 
plt.legend()

# %% [markdown]
# Wizualizacja zbioru testowego i dopasowanego modelu

# %%
y_pred = lin_reg.predict(X_test) 
plt.figure(figsize=(7, 5)) 
plt.title('Regresja Liniowa - jedna zmienna') 
plt.scatter(X_test, y_test, c='g', label='Zbiór testowy')
plt.plot(X, lin_reg.intercept_ + lin_reg.coef_[0] * X, c='red')
plt.xlabel('X') 
plt.ylabel('y') 
plt.legend()

# %% [markdown]
# Ocena modelu

# %%
lin_reg.score(X_test, y_test) # r2 score
# Out:
# 0.8094591241386703
